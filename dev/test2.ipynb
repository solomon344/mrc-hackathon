# %%
import pandas as pd

# %%
df = pd.read_csv('data/predicted_data.csv')
df2 = pd.read_csv('data/meningitis_data.csv')

# %%
df.tail()
# Out:
#            age  sexofthepatient  whitecellcount  csfproteinresult  \
# 2718  0.030000                1             1.0               8.0
# 2719  1.075577                0             1.0               8.0
# 2720  1.075577                0             2.0               8.0
# 2721  1.075577                1             1.0               8.0
# 2722  1.796067                1             3.0               2.0
#
#       csfglucoseresult  csf_gram_resul  csfcultureresults  presenceofseizure  \
# 2718               8.0             3.0           5.000000                1.0
# 2719               8.0             3.0           4.857991                2.0
# 2720               8.0             3.0           5.000000                2.0
# 2721               2.0             3.0           5.000000                1.0
# 2722               2.0             3.0           3.000000                1.0
#
#       neckstiffness  historyoffever  alteredconsciousness  bulgingfontanel  \
# ...

# %%
df2.tail()
# Out:
#       record_id  redcap_repeat_instrument  redcap_repeat_instance  \
# 2718      68996                       NaN                     NaN
# 2719      72517                       NaN                     NaN
# 2720      72528                       NaN                     NaN
# 2721      72544                       NaN                     NaN
# 2722       8396                       NaN                     NaN
#
#      redcap_data_access_group specimenidnumber         medicalwardid  \
# 2718                  tog_chu         TOG03716      TOG_CHU_2016_124
# 2719               ben_chdbor              492  BEN_CHDBOR_2016_0322
# 2720               ben_chdbor              506  BEN_CHDBOR_2016_0333
# 2721               ben_chdbor              529  BEN_CHDBOR_2016_0348
# 2722                 nie_unth              NaN     NIE_UNTH_2016_804
#
#         medicalwardid_sysid   imported_med_rec_id countrycode sentinelsite  \
# ...
